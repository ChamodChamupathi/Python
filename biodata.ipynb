# %%
print("My name is Chamod Chamupathi")
# Out:
# My name is Chamod Chamupathi

# %%
print("I like to develop E-commerce Web Systems")
# Out:
# I am interested in PythonI like to develop E-commerce Web Systems

# %%
print("I am interested in Python")
# Out:
# I am interested in Python
